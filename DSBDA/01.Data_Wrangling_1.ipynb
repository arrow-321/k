# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
weather = pd.read_csv("weatherAUS.csv")
weather.head(7)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# ...

# %%
weather.head(n=4)
# Returns first 4 rows
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1007.1       8.0       NaN     16.9     21.8         No      0.0
# 1       1007.8       NaN       NaN     17.2     24.3         No      0.0
# ...

# %%
weather.tail(n=4)
# Returns last 4 rows
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 142189       NaN           E           31.0         SE  ...        24.0
# 142190       NaN         NNW           22.0         SE  ...        21.0
# 142191       NaN           N           37.0         SE  ...        24.0
# 142192       NaN          SE           28.0        SSE  ...        24.0
#
#         Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 142189       1024.6       1020.3       NaN       NaN     10.1     22.4
# 142190       1023.5       1019.1       NaN       NaN     10.9     24.5
# ...

# %%
weather.index
# Returns the index (row labels) of the dataset
# Out:
# RangeIndex(start=0, stop=142193, step=1)

# %%
weather.columns
# Returns the (column labels) of the dataset
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
weather.shape
# Returns the dimensionality of the Dataset
# Out:
# (142193, 24)

# %%
weather.dtypes
# Returns the data types of the dataset
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
weather.columns.values
# Returns the column values in the array format
# Out:
# array(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall',
#        'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed',
#        'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm',
#        'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm',
#        'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'RainToday',
#        'RISK_MM', 'RainTomorrow'], dtype=object)

# %%
weather.describe(include='all')
# Returns the overall description of the dataset
# Out:
#               Date  Location        MinTemp        MaxTemp       Rainfall  \
# count       142193    142193  141556.000000  141871.000000  140787.000000
# unique        3436        49            NaN            NaN            NaN
# top     2013-12-01  Canberra            NaN            NaN            NaN
# freq            49      3418            NaN            NaN            NaN
# mean           NaN       NaN      12.186400      23.226784       2.349974
# std            NaN       NaN       6.403283       7.117618       8.465173
# min            NaN       NaN      -8.500000      -4.800000       0.000000
# 25%            NaN       NaN       7.600000      17.900000       0.000000
# 50%            NaN       NaN      12.000000      22.600000       0.000000
# 75%            NaN       NaN      16.800000      28.200000       0.800000
# max            NaN       NaN      33.900000      48.100000     371.000000
#
#          Evaporation      Sunshine WindGustDir  WindGustSpeed WindDir9am  ...  \
# ...

# %%
weather['RainToday']
# Reading the data column wise
# Out:
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 142188    No
# 142189    No
# 142190    No
# 142191    No
# 142192    No
# Name: RainToday, Length: 142193, dtype: object

# %%
weather.sort_index(axis=1, ascending=False)
# Sorting the object by labels
# Out:
#         WindSpeed9am  WindSpeed3pm  WindGustSpeed WindGustDir WindDir9am  \
# 0               20.0          24.0           44.0           W          W
# 1                4.0          22.0           44.0         WNW        NNW
# 2               19.0          26.0           46.0         WSW          W
# 3               11.0           9.0           24.0          NE         SE
# 4                7.0          20.0           41.0           W        ENE
# ...              ...           ...            ...         ...        ...
# 142188          15.0          13.0           31.0           E        ESE
# 142189          13.0          11.0           31.0           E         SE
# 142190          13.0           9.0           22.0         NNW         SE
# 142191           9.0           9.0           37.0           N         SE
# 142192          13.0           7.0           28.0          SE        SSE
#
#        WindDir3pm  Temp9am  Temp3pm  Sunshine  Rainfall  ... Pressure3pm  \
# ...

# %%
weather.sort_values(by="WindGustDir")
# Sort values by column name
# Out:
#               Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 21709   2012-01-28  NorfolkIsland     18.3     24.0       1.6          4.4
# 29140   2016-07-03       Richmond     -0.6     16.8       0.0          NaN
# 74860   2015-01-12       Portland     15.8     26.9       0.0          4.0
# 126668  2017-06-20        Walpole     12.2     15.2      21.4          NaN
# 74849   2015-01-01       Portland      8.9     22.1       0.0          6.2
# ...            ...            ...      ...      ...       ...          ...
# 141824  2016-06-18          Uluru      8.7     18.9       0.0          NaN
# 141825  2016-06-19          Uluru      3.4     18.3       0.0          NaN
# 141826  2016-06-20          Uluru      2.2     21.5       0.0          NaN
# 141827  2016-06-21          Uluru      7.8     25.9       0.0          NaN
# 142051  2017-02-02          Uluru     27.5     36.5       0.0          NaN
#
# ...

# %%
weather.iloc[8]
# Integer location based indexing for selection by position
# Out:
# Date             2008-12-09
# Location             Albury
# MinTemp                 9.7
# MaxTemp                31.9
# Rainfall                0.0
# Evaporation             NaN
# Sunshine                NaN
# WindGustDir             NNW
# WindGustSpeed          80.0
# WindDir9am               SE
# WindDir3pm               NW
# WindSpeed9am            7.0
# WindSpeed3pm           28.0
# Humidity9am            42.0
# Humidity3pm             9.0
# Pressure9am          1008.9
# Pressure3pm          1003.6
# Cloud9am                NaN
# Cloud3pm                NaN
# Temp9am                18.3
# Temp3pm                30.2
# RainToday                No
# RISK_MM                 1.4
# RainTomorrow            Yes
# Name: 8, dtype: object

# %%
weather[1:5]
# Prints the rows from 1 to 4
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 1       1007.8       NaN       NaN     17.2     24.3         No      0.0
# 2       1008.7       NaN       2.0     21.0     23.2         No      0.0
# ...

# %%
weather.loc[:,["MinTemp","Location"]]
# Selection by labels
# Out:
#         MinTemp Location
# 0          13.4   Albury
# 1           7.4   Albury
# 2          12.9   Albury
# 3           9.2   Albury
# 4          17.5   Albury
# ...         ...      ...
# 142188      3.5    Uluru
# 142189      2.8    Uluru
# 142190      3.6    Uluru
# 142191      5.4    Uluru
# 142192      7.8    Uluru
#
# [142193 rows x 2 columns]

# %%
weather.iloc[:2, :]
# Prints first two rows for all columns
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1007.1       8.0       NaN     16.9     21.8         No      0.0
# 1       1007.8       NaN       NaN     17.2     24.3         No      0.0
#
#    RainTomorrow
# 0            No
# 1            No
#
# [2 rows x 24 columns]

# %%
weather.iloc[:, :4]
# Prints all rows with first 4 columns
# Out:
#               Date Location  MinTemp  MaxTemp
# 0       2008-12-01   Albury     13.4     22.9
# 1       2008-12-02   Albury      7.4     25.1
# 2       2008-12-03   Albury     12.9     25.7
# 3       2008-12-04   Albury      9.2     28.0
# 4       2008-12-05   Albury     17.5     32.3
# ...            ...      ...      ...      ...
# 142188  2017-06-20    Uluru      3.5     21.8
# 142189  2017-06-21    Uluru      2.8     23.4
# 142190  2017-06-22    Uluru      3.6     25.3
# 142191  2017-06-23    Uluru      5.4     26.9
# 142192  2017-06-24    Uluru      7.8     27.0
#
# [142193 rows x 4 columns]

# %%
weather.iloc[2:4, 1:2]
# Prints the rows 2 & 3 with column 1
# Out:
#   Location
# 2   Albury
# 3   Albury

# %%
weather.iloc[[1,2,5],[1,4]]
# Prints rows 1,2,&5 with the columns 1 & 4
# Out:
#   Location  Rainfall
# 1   Albury       0.0
# 2   Albury       0.0
# 5   Albury       0.2

# %%
weather["WindGustDir"].iloc[5:8]
# Prints the values for column WindGustDir for rows 5,6,& 7
# Out:
# 5    WNW
# 6      W
# 7      W
# Name: WindGustDir, dtype: object
